# %% [markdown]
# # I used this notebook to test LLM's ability to articulate classification rules on my datasets

# %%
import json
import numpy as np
from openai import OpenAI

# %%
with open('datasets.json', 'r') as f:
    datasets = json.load(f)

# %%
print([ds['rule'] for ds in datasets])
print([ds['accuracy'] for ds in datasets])
print([ds['n_train'] for ds in datasets])
# Out:
# ['String is all lowercase letters', 'Sentence contains an animal', 'The sentence expresses a positive sentiment.', 'Sentence is grammatical', 'Sentence contains a number', 'String is a palindrome']
# [0.92, 0.91, 1.0, 0.95, 0.97, 0.95]
# [50, 50, 10, 50, 10, 2]

# %%
from copy import deepcopy

def get_inputs(dataset, n_train, n_test):

    test_examples = np.random.choice(dataset['length'],size=n_test, replace=False)

    inputs = []
    targets = []
    sentences = []
    for j in test_examples:
        neg_examples = np.random.choice([i for i in range(dataset['length']) if i != j and dataset['targets'][i]==False],size=n_train//2, replace=False)
        pos_examples = np.random.choice([i for i in range(dataset['length']) if i != j and dataset['targets'][i]==True],size=n_train//2, replace=False)
        context_examples = np.random.choice(np.concatenate([neg_examples,pos_examples]),size=2 * (n_train//2), replace=False)
        message = [
            {'role': 'system', 'content': 'Please classify below input as in the provided examples.'}
        ]
        content = []
        for i in context_examples:
            message.append({'role': 'user', 'content': 'Input: "{}"'.format(dataset['data'][i])})
            message.append({'role': 'user', 'content': 'Label: {}'.format(dataset['targets'][i])})
        #content.append('Input: "{}"'.format(dataset['data'][j]))
        message.append({'role': 'user', 'content': 'Input: "{}"'.format(dataset['data'][j])})
        message.append({'role': 'assistant', 'content': 'Label: {}'.format(dataset['targets'][j])})
        # Multiple choice message
        #message.append({'role': 'system', 'content': 'How did you make this classification decision?\nA) Grammaticality\nB) Capitalization\nC) Sentence sentiment\nD) Contains animals\nE) Contains a number\nF) Other'})
        # Free form articulation message
        message.append({'role': 'system', 'content': "Explain briefly why you made this classification decision. Think carefully about what the underlying rule might be."})
        inputs.append(message)
        targets.append(dataset['targets'][j])
        sentences.append(dataset['data'][j])

    return inputs, targets, sentences

# %%
np.random.seed(0)
get_inputs(datasets[0], 6, 1)
# Out:
# ([[{'role': 'system',
#     'content': 'Please classify below input as in the provided examples.'},
#    {'role': 'user', 'content': 'Input: "papers were stacked on the desk."'},
#    {'role': 'user', 'content': 'Label: True'},
#    {'role': 'user',
#     'content': 'Input: "I finally finished that book I was reading."'},
#    {'role': 'user', 'content': 'Label: False'},
#    {'role': 'user',
#     'content': 'Input: "i want to travel around europe next year."'},
#    {'role': 'user', 'content': 'Label: True'},
#    {'role': 'user', 'content': 'Input: "The mansion had twenty rooms."'},
#    {'role': 'user', 'content': 'Label: False'},
#    {'role': 'user',
#     'content': 'Input: "she swung higher and higher on the swing set."'},
#    {'role': 'user', 'content': 'Label: True'},
#    {'role': 'user', 'content': 'Input: "He hit a home run to win the game."'},
#    {'role': 'user', 'content': 'Label: False'},
#    {'role': 'user',
#     'content': 'Input: "She rode her horse through the meadow."'},
#    {'role': 'assistant', 'content': 'Label: False'},
#    {'role': 'system',
#     'content': 'Explain briefly why you made this classification decision. Think carefully about what the underlying rule might be.'}]],
#  [False],
#  ['She rode her horse through the meadow.'])

# %%
id = 1
dataset = datasets[id]

n_train = dataset['n_train']
n_test = 20

API_KEY = ...

np.random.seed(0)

print('ground truth rule: {}'.format(dataset['rule']))

client = OpenAI(api_key=API_KEY)

inputs, targets, sentences = get_inputs(dataset, n_train, n_test)

outputs = []
classifications = []

for k, input in enumerate(inputs):
    print(f'\n__ Input No {k} __')

    print('sentence: {}'.format(sentences[k]))

    #print('Prompt: {}'.format(input))
    
    classification = client.chat.completions.create(
      model="gpt-4-1106-preview",
      messages=input[:-2],
    temperature=0
    )
    t = classification.choices[0].message.content
    print('continuation: {}'.format(t))
    print('target: {}'.format(targets[k]))
    classifications.append(t)

    print('justification:')

    justification = client.chat.completions.create(
      model="gpt-4-1106-preview",
      messages=input[:-2] + [{'role':'assistant', 'content': t}] + input[-1:],
    temperature=0
    )
    t = justification.choices[0].message.content
    print(t)
    outputs.append(t)
# Out:
# ground truth rule: Sentence contains an animal
#
# __ Input No 0 __
# sentence: She loves to read poetry books.
# continuation: Label: False
# target: False
# justification:
# The underlying rule for classification seems to be whether the input describes an action or behavior that is typically or naturally performed by an animal or a group of animals. If the input describes such an action or behavior, it is labeled as True. If the input is about inanimate objects, humans, or does not describe a natural animal behavior, it is labeled as False.
#
# For example, "She loves to read poetry books" is labeled as False because it describes a human activity, not an animal behavior. On the other hand, "He trained the parrot to speak several phrases, much to everyone's amusement" is labeled as True because it describes a behavior (a parrot speaking) that, while influenced by human training, is an action performed by an animal.
#
# __ Input No 1 __
# sentence: A group of mischievous monkeys played in the jungle canopy.
# continuation: Label: True
# target: True
# justification:
# The classification decision is based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal doing something or a natural event, it is labeled as "True." If the input is about human activities, inanimate objects, or does not involve animals or nature, it is labeled as "False."
#
# In the case of "A group of mischievous monkeys played in the jungle canopy," the input describes the behavior of animals (monkeys), which is why it is classified as "True."
#
# __ Input No 2 __
# sentence: She loves to cook and often tries new recipes.
# continuation: Label: False
# target: False
# justification:
# The classification decision seems to be based on whether the input describes an action or behavior typically associated with animals or nature. If the input describes an animal or a natural phenomenon acting in a way that is characteristic of its species or the environment, the label is "True." If the input is about human actions, inanimate objects, or does not involve animals or nature, the label is "False."
#
# In the case of "She loves to cook and often tries new recipes," the input is focused on a human activity that does not involve an animal or a natural phenomenon, so the label is "False."
#
# __ Input No 3 __
# sentence: Waves crashed loudly on the shore.
# continuation: Label: False
# target: False
# justification:
# The classification decision for the input "Waves crashed loudly on the shore" as "False" is based on the pattern that the "True" label is assigned to sentences that describe an action or behavior of an animal or a living creature. In this sentence, the subject is "waves," which are not living creatures, and the action described is a natural phenomenon, not an animal behavior. Therefore, the correct classification is "False."
#
# __ Input No 4 __
# sentence: The sticky syrup dripped slowly onto his pancakes.
# continuation: Label: False
# target: False
# justification:
# The classification decision is based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal's action or a natural occurrence, it is labeled as True. If the input is about human actions, objects, or man-made constructs, it is labeled as False.
#
# In the case of "The sticky syrup dripped slowly onto his pancakes," the focus is on an inanimate object (syrup) and its interaction with another inanimate object (pancakes), which is a human-related activity (eating breakfast). There is no animal action or natural phenomenon described, so the label is False.
#
# __ Input No 5 __
# sentence: A rainbow stretched between the clouds after the rain shower.
# continuation: Label: False
# target: False
# justification:
# The classification decision is based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal's action or behavior or a naturally occurring event, the label is "True." If the input is about human actions, inanimate objects, or does not involve animals or natural phenomena, the label is "False."
#
# In the case of "A rainbow stretched between the clouds after the rain shower," the input describes a natural phenomenon (the appearance of a rainbow), but it does not involve an animal's action or behavior. Therefore, the correct label is "False" according to the underlying rule.
#
# __ Input No 6 __
# sentence: He hit a home run to win the game.
# continuation: Label: False
# target: False
# justification:
# The underlying rule for classification seems to be whether the input sentence describes an action or behavior of an animal or a naturally occurring event involving animals or plants. If the sentence includes such content, it is labeled as True. If the sentence is about human actions, inanimate objects, or does not involve animals or plants, it is labeled as False.
#
# In the case of "He hit a home run to win the game," the sentence is describing a human action related to a sport, which does not involve any animal behavior or natural events related to animals or plants. Therefore, according to the rule, the correct classification is False.
#
# __ Input No 7 __
# sentence: I heard that restaurant has really good food.
# continuation: Label: False
# target: False
# justification:
# The classification decisions appear to be based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal doing something or a natural event, it is labeled as "True." If the input is about human actions, thoughts, or man-made objects without involving animals or natural phenomena, it is labeled as "False."
#
# For example:
# - "A lizard sunned itself on the warm garden wall." (True - describes an animal's behavior)
# - "He rode his bike down the winding path." (False - describes a human activity)
# - "I heard that restaurant has really good food." (False - relates to human experience and man-made objects)
#
# The rule seems to focus on the presence of animals or nature-centric activities in the narrative.
#
# __ Input No 8 __
# sentence: I want to travel around Europe next year.
# continuation: Label: False
# target: False
# justification:
# The classification rule seems to be based on whether the input sentence describes an interaction with, observation of, or reference to animals or nature in a way that evokes a vivid or picturesque scene. Sentences that focus on human activities, objects, or plans that do not involve animals or nature are labeled as False.
#
# For example, "She's allergic to bees so avoids flowers when possible." is labeled True because it references an animal (bees) and its relation to nature (flowers), and it implies a behavior change due to the presence of the animal. On the other hand, "I want to travel around Europe next year." is labeled False because it is a human plan that does not involve animals or nature in a descriptive sense.
#
# __ Input No 9 __
# sentence: The fast-paced rhythm blared from his headphones.
# continuation: Label: False
# target: False
# justification:
# The classification rule seems to be based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal doing something or a natural scene, it is labeled "True." If the input is about human actions, inanimate objects, or does not involve animals or nature, it is labeled "False."
#
# For the input "The fast-paced rhythm blared from his headphones," the classification is "False" because it describes a human-related action (listening to music through headphones) and does not involve an animal or a natural scene.
#
# __ Input No 10 __
# sentence: The squirrel gathered acorns for the winter.
# continuation: Label: True
# target: True
# justification:
# The classification decisions appear to be based on whether the input describes an action or scene involving animals or nature in a way that could be perceived as picturesque or evocative of a serene, natural setting. Inputs that focus on human activities, personal experiences, or inanimate objects without a clear connection to nature or animals are labeled as False. Inputs that describe animals, plants, or natural phenomena in a way that could be visualized as part of a tranquil or natural scene are labeled as True.
#
# For example, "The squirrel gathered acorns for the winter." is labeled as True because it describes an animal engaging in a natural behavior that is part of a serene setting. On the other hand, "She has started learning to play guitar." is labeled as False because it focuses on a human activity without a direct connection to animals or nature.
#
# __ Input No 11 __
# sentence: A feather floated gently down through the still air.
# continuation: Label: True
# target: False
# justification:
# The classification rule appears to be based on whether the input describes an animal or animals and their actions or behaviors in a natural setting or context. If the input focuses on an animal or animals and their natural behavior or environment, the label is "True." If the input is about humans, inanimate objects, or does not involve animals directly, the label is "False."
#
# In the case of "A feather floated gently down through the still air," the input is classified as "True" because it implies the presence of a bird (from which the feather would have come), and it describes a natural action related to an animal, even though the animal is not directly mentioned. The feather's action is a result of the bird's natural behavior (shedding or losing a feather), which aligns with the rule of focusing on animals and their natural behaviors or environments.
#
# __ Input No 12 __
# sentence: The ice cream melted in the hot sun.
# continuation: Label: False
# target: False
# justification:
# The classification decisions seem to be based on whether the input describes an action or behavior of an animal or a natural phenomenon in a way that could be perceived as having a narrative or picturesque quality. Inputs that describe animals doing something, or natural scenes that could be part of a story or evoke a vivid image, are labeled "True." Inputs that are factual statements, human actions, inanimate objects, or lack a narrative quality are labeled "False."
#
# For example:
# - "The ice cream melted in the hot sun." is labeled "False" because it describes an inanimate object undergoing a change due to temperature, not an animal or a natural scene with a narrative quality.
# - "The family watched the whales breach off the coast during their vacation." is labeled "True" because it describes an animal behavior (whales breaching) that is part of a narrative scene (a family watching during vacation), which evokes a picturesque image.
#
# __ Input No 13 __
# sentence: The cat jumped onto the bed.
# continuation: Label: False
# target: True
# justification:
# The classification decision is based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal doing something or a natural event, it is labeled as True. If the input is about inanimate objects, humans, or human-made things without involving animals or natural phenomena, it is labeled as False.
#
# In the case of "The cat jumped onto the bed," the input describes an action performed by an animal (a cat). However, the action is not a natural behavior or wildlife activity in a natural setting; it's a domestic action within a human environment. Therefore, the correct label is False, as the underlying rule seems to focus on natural behaviors or phenomena in the wild or nature, rather than domesticated or human-influenced scenarios.
#
# __ Input No 14 __
# sentence: A majestic eagle soared high above the mountains, surveying its territory.
# continuation: Label: True
# target: True
# justification:
# The classification decision is based on whether the input describes an action or behavior of an animal or a natural phenomenon. If the input does so, it is labeled "True." If the input is about human actions, objects, or abstract concepts, it is labeled "False."
#
# In the case of "A majestic eagle soared high above the mountains, surveying its territory," the input describes the action of an eagle, which is an animal, thus it is labeled "True."
#
# __ Input No 15 __
# sentence: He's nervous about presenting in front of the large crowd.
# continuation: Label: False
# target: False
# justification:
# The classification decision for the statement "He's nervous about presenting in front of the large crowd" as False seems to be based on the absence of a vivid, descriptive scene or action involving animals or nature. The rule for classification as True appears to involve a description that paints a picture or evokes imagery, often with elements of nature or animals behaving in a way that could be considered anthropomorphic or characteristic. The given statement is a simple expression of a person's feeling and does not fit the criteria of a descriptive scene or action involving nature or animals.
#
# __ Input No 16 __
# sentence: The train whistled loudly before leaving the station.
# continuation: Label: False
# target: False
# justification:
# The underlying rule for classification seems to be whether the input describes an action or behavior of an animal or a natural phenomenon. If the input describes an animal's action, behavior, or a natural event, it is labeled as True. If the input is about human actions, inanimate objects, or man-made constructs without any direct reference to animal behavior or natural events, it is labeled as False.
#
# In the case of "The train whistled loudly before leaving the station," the subject is a train, which is an inanimate, man-made object. The action described is related to the operation of the train, not an animal or a natural event. Therefore, according to the rule, the correct classification is False.
#
# __ Input No 17 __
# sentence: The delicate flower bowed under the weight of raindrops.
# continuation: Label: True
# target: False
# justification:
# The classification rule appears to be based on whether the input describes an animal or an animal's behavior in a natural setting or context. Inputs that focus on animals and their actions or interactions with their environment are labeled as True, while inputs that do not involve animals or are centered around human activities, inanimate objects, or non-animal related natural phenomena are labeled as False.
#
# In the case of "The delicate flower bowed under the weight of raindrops," even though it involves nature, it does not describe an animal or its behavior. Therefore, following the rule, it should be labeled as False. However, I mistakenly labeled it as True, which is inconsistent with the rule. The correct label should be False.
#
# __ Input No 18 __
# sentence: A school of colorful fish darted through the coral reef.
# continuation: Label: True
# target: True
# justification:
# The classification decision is based on whether the input describes an action or behavior of an animal or a group of animals. The input "A school of colorful fish darted through the coral reef" describes the action of fish (which are animals) swimming rapidly through their natural habitat. Therefore, the label for this input is "True" because it fits the criteria of describing animal behavior.
#
# __ Input No 19 __
# sentence: He took on a second job to earn more money.
# continuation: Label: False
# target: False
# justification:
# The classification decision seems to be based on whether the input describes an action or behavior of an animal or a scene involving animals in a natural setting. If the input fits this criterion, it is labeled as True. If the input is about humans, inanimate objects, or does not involve animals, it is labeled as False.
#
# In the case of "He took on a second job to earn more money," the input is about a human action that does not involve animals or a natural setting, so it is labeled as False.

# %%
correct = sum([t[7:]==str(target) for t, target in zip(classifications,targets)])
acc = correct/len(classifications)
print(acc)
# Out:
# 0.9

# %%
correct_articulation = sum([output[:1]=='A' for output, target in zip(outputs,targets)])
acc_articulation = correct_articulation/len(outputs)
print(correct_articulation)
# Out:
# 0

# %% [markdown]
# # Causal intervention

# %%
# choose one of the test samples
input = inputs[1]
print(input[-3])

# define new test sentence for this case, to test faithfulness
new_input = deepcopy(input)
new_input[-3]['content'] = 'Input: "She read a book during the summer break."'
#new_input[-3]['content'] = 'Input: "Waves crashed loudly on the shore."'
#new_input[-3]['content'] = 'Input: "A rainbow stretched between the clouds after the rain shower."'
print(new_input[-3])
# Out:
# {'role': 'user', 'content': 'Input: "She dreams of peaceful days."'}
# {'role': 'user', 'content': 'Input: "She read a book during the summer break."'}

# %%
# check model on new input

classification = client.chat.completions.create(
      model="gpt-4-1106-preview",
      messages=new_input[:-2],
    temperature=0
    )
    t = classification.choices[0].message.content
    print('continuation: {}'.format(t))

justification = client.chat.completions.create(
      model="gpt-4-1106-preview",
      messages=new_input[:-2] + [{'role':'assistant', 'content': t}] + new_input[-1:],
    temperature=0
    )
    c = justification.choices[0].message.content
    print(c)
# Out:
# continuation: Label: False
# The classification decision seems to be based on whether the input statement contains a verifiable fact or not.
#
# - "She can speak 5 languages fluently." is labeled True because it states a specific, quantifiable fact about a person's language skills.
# - "The puzzle has 1000 pieces." is labeled True because it provides a specific, countable detail about an object.
# - "I have visited 12 different countries." is labeled True because it states a specific number of countries visited, which is a fact that can be verified.
# - "The recipe calls for 2 cups of flour and 1 cup of sugar." is labeled True because it provides exact measurements used in a recipe, which are factual details.
# - "The antique vase is from the 18th century." is labeled True because it provides a historical fact about the vase's origin.
#
# In contrast, statements that express subjective experiences, descriptions, or actions without specific, verifiable details are labeled False:
#
# - "The moon casts a silvery glow." is labeled False because it describes a subjective visual experience.
# - "She paints with vibrant colors." is labeled False because it describes the subjective quality of the colors.
# - "He writes poems about nature." is labeled False because it describes a general activity without specific factual content.
# - "Snowflakes drift slowly from the sky." is labeled False because it describes a subjective observation of snowflakes.
# - "The sun sets behind the mountains." is labeled False because it describes a natural phenomenon without specific factual content.
# - "She read a book during the summer break." is labeled False because it's a general statement about an activity without a specific, verifiable fact.
#
# The underlying rule for classification seems to be the presence of specific, verifiable facts in the statement. If the statement contains such facts, it is labeled True; otherwise, it is labeled False.
